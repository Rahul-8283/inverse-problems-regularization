# %% [markdown]
# # Tikhonov Regularization — Image Reconstruction
#
# ## Inverse Problem
#
# $$
# y = A\,x + \varepsilon
# $$
#
# ## Tikhonov Regularization
#
# Solve the penalised least-squares problem:
#
# $$
# x_\lambda = \arg\min_x \bigl\{\|A\,x - y\|^2 + \lambda\,\|x\|^2\bigr\}
# $$
#
# The closed-form solution is:
#
# $$
# x_\lambda = (A^T A + \lambda I)^{-1}\, A^T y
# $$
#
# For large images this is solved iteratively via gradient descent:
#
# $$
# x^{(k+1)} = x^{(k)} - \tau\bigl[A^T(Ax^{(k)} - y) + \lambda\, x^{(k)}\bigr]
# $$
#
# ## Error Metrics
#
# $$
# \text{MSE} = \frac{1}{N}\sum_{i=1}^{N}(x_i^{\text{rec}} - x_i^{\text{true}})^2, \qquad
# \text{Relative Error} = \frac{\|x^{\text{rec}} - x^{\text{true}}\|}{\|x^{\text{true}}\|}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve2d

# %%
image_path = r"296059.jpg"


img = plt.imread(image_path)


if img.ndim == 3:
    img = img.mean(axis=2)


x_true = img.astype(float)
x_true /= x_true.max()


print("Image shape:", x_true.shape)
# Out:
# Image shape: (321, 481)

# %%
def gaussian_kernel(size=9, sigma=2.0):
    ax = np.linspace(-(size // 2), size // 2, size)
    xx, yy = np.meshgrid(ax, ax)
    kernel = np.exp(-(xx**2 + yy**2) / (2 * sigma**2))
    kernel /= kernel.sum()
    return kernel


kernel = gaussian_kernel(size=9, sigma=2.0)

# %%
def A_op(x):
    return convolve2d(x, kernel, mode="same", boundary="symm")


def AT_op(x):
    flipped = np.flipud(np.fliplr(kernel))
    return convolve2d(x, flipped, mode="same", boundary="symm")

# %%
noise_std = 0.01
Ax = A_op(x_true)
eps = noise_std * np.random.randn(*Ax.shape)
y = Ax + eps

# %%
def tikhonov_operator(y, lam, n_iter=200, tau=0.1):
    x = np.zeros_like(y)
    for _ in range(n_iter):
        grad = AT_op(A_op(x) - y) + lam * x
        x -= tau * grad
    return x

# %%
lambdas = [1e-4, 1e-3, 1e-2, 1e-1]
errors_tikh = []

plt.figure(figsize=(12,8))
for i, lam in enumerate(lambdas):
    x_rec = tikhonov_operator(y, lam)
    rel_err = np.linalg.norm(x_rec - x_true) / np.linalg.norm(x_true)
    mse_val = np.mean((x_rec - x_true) ** 2)
    errors_tikh.append((lam, rel_err, mse_val))
    plt.subplot(2,2,i+1)
    plt.imshow(x_rec, cmap="gray")
    plt.title(f"Tikhonov (\u03bb={lam}), Error={rel_err:.4f}")
    plt.axis("off")


plt.tight_layout()
plt.show()

print("="*50)
print("TIKHONOV RECONSTRUCTION ERROR ANALYSIS")
print("="*50)
for lam, err, mse_val in errors_tikh:
    print(f"\u03bb = {lam:.0e}: Relative error = {err:.6f}, MSE = {mse_val:.8f}")
best_lam, best_err, best_mse = min(errors_tikh, key=lambda x: x[2])
print(f"\nBest \u03bb: {best_lam:.0e}")
print(f"Best Relative Error: {best_err:.6f}")
print(f"Best MSE: {best_mse:.8f}")
print(f"Image size: {x_true.shape[0]}x{x_true.shape[1]}")
print(f"Kernel size: 9x9, Kernel/Image ratio: {9/x_true.shape[0]:.2f}")
# Out:
# ...
# TIKHONOV RECONSTRUCTION ERROR ANALYSIS
# ...
# λ = 1e-04: Relative error = 0.086380, MSE = 0.00129857
# λ = 1e-03: Relative error = 0.086406, MSE = 0.00129935
# λ = 1e-02: Relative error = 0.087206, MSE = 0.00132349
# λ = 1e-01: Relative error = 0.128097, MSE = 0.00285569
#
# Best λ: 1e-04
# Best Relative Error: 0.086380
# Best MSE: 0.00129857
# Image size: 321x481
# Kernel size: 9x9, Kernel/Image ratio: 0.03
